# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from collections import Counter

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
mcu_data = pd.read_csv('./mcu_box_office.csv')

# %%
mcu_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           27 non-null     object
#  1   mcu_phase             27 non-null     int64
#  2   release_date          27 non-null     object
#  3   tomato_meter          27 non-null     int64
#  4   audience_score        27 non-null     int64
#  5   movie_duration        27 non-null     int64
#  6   production_budget     27 non-null     object
#  7   opening_weekend       27 non-null     object
#  8   domestic_box_office   27 non-null     object
#  9   worldwide_box_office  27 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 2.2+ KB

# %%
mcu_data.head()
# Out:
#                           movie_title  mcu_phase release_date  tomato_meter  \
# 0                            Iron Man          1     5/2/2008            94
# 1                 The Incredible Hulk          1    6/13/2008            67
# 2                          Iron Man 2          1     5/7/2010            72
# 3                                Thor          1     5/6/2011            77
# 4  Captain America: The First Avenger          1    7/22/2011            79
#
#    audience_score  movie_duration production_budget opening_weekend  \
# 0              91             126       186,000,000     102,118,668
# 1              70             112       137,500,000      55,414,050
# 2              71             124       170,000,000     128,122,480
# 3              76             113       150,000,000      65,723,338
# 4              75             124       140,000,000      65,058,524
#
#   domestic_box_office worldwide_box_office
# 0         318,604,126          585,171,547
# 1         134,806,913          265,573,859
# 2         312,433,331          621,156,389
# 3         181,030,624          449,326,618
# 4         176,654,505          370,569,776

# %%
money_columns = ['production_budget', 'opening_weekend', 'domestic_box_office', 'worldwide_box_office']
for col in money_columns:
    mcu_data[col] = mcu_data[col].str.replace(',', '').astype(int)

# %%
mcu_data['release_date'] = pd.to_datetime(mcu_data['release_date'])
mcu_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           27 non-null     object
#  1   mcu_phase             27 non-null     int64
#  2   release_date          27 non-null     datetime64[ns]
#  3   tomato_meter          27 non-null     int64
#  4   audience_score        27 non-null     int64
#  5   movie_duration        27 non-null     int64
#  6   production_budget     27 non-null     int64
#  7   opening_weekend       27 non-null     int64
#  8   domestic_box_office   27 non-null     int64
#  9   worldwide_box_office  27 non-null     int64
# dtypes: datetime64[ns](1), int64(8), object(1)
# memory usage: 2.2+ KB

# %%
mcu_data['net_profit'] = mcu_data['worldwide_box_office'] - mcu_data['production_budget']

# %%
critic_ranked = mcu_data.sort_values('tomato_meter', ascending=False)
viewer_rating = mcu_data.sort_values('audience_score', ascending=False)
worldwide_box_office = mcu_data.sort_values('worldwide_box_office', ascending=False)
opening_weekend = mcu_data.sort_values('opening_weekend', ascending=False)
net_profit = mcu_data.sort_values('net_profit', ascending=False)

# %%
standings = Counter(mcu_data['movie_title'])
for title in standings:
    standings[title] = 0

# %%
labels = {
    'tomato_meter': 'Critic Score',
    'audience_score': 'Audience Score',
    'worldwide_box_office': 'Worldwide Box Office Earnings',
    'opening_weekend': 'Opening Weekend Earnings',
    'net_profit': 'Net Profit Earnings'
}

# %%
def addPointsToStandings(data, standings):
    for (i, title) in enumerate(data):
        points = 27 - i
        standings[title] += points
    return standings

# %%
def displayBarGraph(df, x_val):
    data = df.head(10)
    label = labels[x_val]
    fig, ax = plt.subplots(figsize=(20,8))
    sns.set_context('talk')
    sns.barplot(y='movie_title', x=x_val, data=data, ax=ax, hue='mcu_phase', dodge=False)
    plt.ylabel('MCU Movie Titles')
    plt.xlabel(label)
    plt.title(f'Top 10 MCU Movies Ranked by {label}')
    ax.legend(loc='center right', bbox_to_anchor=(1.12, 0.5), fancybox=True, shadow=True, title='MCU Phase')
    plt.show()

# %%
standings = addPointsToStandings(critic_ranked['movie_title'], standings)
print(standings.most_common(10))
# Out:
# [('Black Panther', 27), ('Iron Man', 26), ('Avengers: End Game', 25), ('Thor: Ragnarok', 24), ('Spider-Man: No Way Home', 23), ('Guardians of the Galaxy', 22), ('Spider-Man: Homecoming', 21), ('The Avengers', 20), ('Shang-Chi and the Legend of the Ten Rings', 19), ('Captain America: Civil War', 18)]

# %%
displayBarGraph(critic_ranked, 'tomato_meter')

# %%
standings = addPointsToStandings(viewer_rating['movie_title'], standings)
print(standings.most_common(10))
# Out:
# [('Spider-Man: No Way Home', 50), ('Iron Man', 46), ('Guardians of the Galaxy', 45), ('Shang-Chi and the Legend of the Ten Rings', 45), ('Avengers: End Game', 43), ('Captain America: The Winter Soldier', 41), ('Spider-Man: Far From Home', 41), ('The Avengers', 39), ('Thor: Ragnarok', 38), ('Spider-Man: Homecoming', 36)]

# %%
displayBarGraph(viewer_rating, 'audience_score')

# %%
standings = addPointsToStandings(worldwide_box_office['movie_title'], standings)
print(standings.most_common(10))
# Out:
# [('Spider-Man: No Way Home', 75), ('Avengers: End Game', 70), ('The Avengers', 63), ('Spider-Man: Far From Home', 60), ('Guardians of the Galaxy', 59), ('Avengers: Infinity War', 59), ('Black Panther', 58), ('Captain America: Civil War', 55), ('Iron Man', 54), ('Captain America: The Winter Soldier', 54)]

# %%
displayBarGraph(worldwide_box_office, 'worldwide_box_office')

# %%
standings = addPointsToStandings(opening_weekend['movie_title'], standings)
print(standings.most_common(10))
# Out:
# [('Spider-Man: No Way Home', 101), ('Avengers: End Game', 97), ('The Avengers', 87), ('Avengers: Infinity War', 84), ('Black Panther', 81), ('Captain America: Civil War', 76), ('Guardians of the Galaxy', 71), ('Spider-Man: Far From Home', 71), ('Thor: Ragnarok', 69), ('Iron Man', 68)]

# %%
displayBarGraph(opening_weekend, 'opening_weekend')

# %%
standings = addPointsToStandings(net_profit['movie_title'], standings)
print(standings.most_common(10))
# Out:
# [('Spider-Man: No Way Home', 126), ('Avengers: End Game', 124), ('The Avengers', 111), ('Avengers: Infinity War', 110), ('Black Panther', 104), ('Captain America: Civil War', 94), ('Spider-Man: Far From Home', 91), ('Guardians of the Galaxy', 85), ('Spider-Man: Homecoming', 85), ('Thor: Ragnarok', 85)]

# %%
displayBarGraph(net_profit, 'net_profit')

# %%
mcu_data['points_scored'] = standings.values()

# %%
mcu_data.sort_index(axis=0, ascending=True)
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1   2008-05-02
# 1                         The Incredible Hulk          1   2008-06-13
# 2                                  Iron Man 2          1   2010-05-07
# 3                                        Thor          1   2011-05-06
# 4          Captain America: The First Avenger          1   2011-07-22
# 5                                The Avengers          1   2012-05-04
# 6                                  Iron Man 3          2   2013-05-03
# 7                        Thor: The Dark World          2   2013-11-08
# 8         Captain America: The Winter Soldier          2   2014-04-04
# 9                     Guardians of the Galaxy          2   2014-08-01
# 10                    Avengers: Age of Ultron          2   2015-05-01
# 11                                    Ant-Man          2   2015-07-17
# 12                 Captain America: Civil War          3   2016-05-06
# 13                             Doctor Strange          3   2016-11-04
# 14             Guardians of the Galaxy Vol. 2          3   2017-05-05
# 15                     Spider-Man: Homecoming          3   2017-07-07
# 16                             Thor: Ragnarok          3   2017-11-03
# 17                              Black Panther          3   2018-02-16
# 18                     Avengers: Infinity War          3   2018-04-27
# 19                       Ant-Man and the Wasp          3   2018-07-06
# 20                             Captain Marvel          3   2019-03-08
# 21                         Avengers: End Game          3   2019-04-26
# 22                  Spider-Man: Far From Home          3   2019-07-02
# 23                                Black Widow          4   2021-07-09
# 24  Shang-Chi and the Legend of the Ten Rings          4   2021-09-03
# 25                                   Eternals          4   2021-11-05
# 26                    Spider-Man: No Way Home          4   2021-12-17
#
#     tomato_meter  audience_score  movie_duration  production_budget  \
# 0             94              91             126          186000000
# 1             67              70             112          137500000
# 2             72              71             124          170000000
# 3             77              76             113          150000000
# 4             79              75             124          140000000
# 5             91              91             143          225000000
# 6             79              78             130          200000000
# 7             66              75             111          150000000
# 8             90              92             135          170000000
# 9             92              92             121          170000000
# 10            76              83             141          365000000
# 11            83              85             117          130000000
# 12            90              89             146          250000000
# 13            89              86             115          165000000
# 14            85              87             135          200000000
# 15            92              87             133          175000000
# 16            93              87             130          180000000
# 17            96              79             134          200000000
# 18            85              91             149          300000000
# 19            87              81             118          130000000
# 20            79              45             124          175000000
# 21            94              90             181          400000000
# 22            90              95             129          160000000
# 23            79              91             133          200000000
# 24            91              98             133          150000000
# 25            47              78             157          200000000
# 26            93              98             148          200000000
#
#     opening_weekend  domestic_box_office  worldwide_box_office  net_profit  \
# 0         102118668            318604126             585171547   399171547
# 1          55414050            134806913             265573859   128073859
# 2         128122480            312433331             621156389   451156389
# 3          65723338            181030624             449326618   299326618
# 4          65058524            176654505             370569776   230569776
# 5         207438708            623357910            1515100211  1290100211
# 6         174144585            408992272            1215392272  1015392272
# 7          85737841            206362140             644602516   494602516
# 8          95023721            259746958             714401889   544401889
# 9          94320883            333714112             770882395   600882395
# 10        191271109            459005868            1395316979  1030316979
# 11         57225526            180202163             518858449   388858449
# 12        179139142            408084349            1151918521   901918521
# 13         85058311            232641920             676354481   511354481
# 14        146510104            389813101             869113101   669113101
# 15        117027503            334201140             878346440   703346440
# 16        122744989            315058289             850482778   670482778
# 17        202003951            700059566            1336494321  1136494321
# 18        257698183            678815482            2048359754  1748359754
# 19         75812205            216648740             623144660   493144660
# 20        153433423            426829839            1129727388   954727388
# 21        357115007            858373000            2797800564  2397800564
# 22         92579212            390532085            1132532832   972532832
# 23         80366312            183651655             379751655   179751655
# 24         75388688            224543292             432243292   282243292
# 25         71297219            164870264             402064929   202064929
# 26        260138569            803975784            1891108035  1691108035
#
#     points_scored
# 0              76
# 1               8
# 2              42
# 3              28
# 4              21
# 5             111
# 6              80
# 7              38
# 8              80
# 9              85
# 10             83
# 11             39
# 12             94
# 13             61
# 14             78
# 15             85
# 16             85
# 17            104
# 18            110
# 19             51
# 20             66
# 21            124
# 22             91
# 23             43
# 24             61
# 25             20
# 26            126

# %%
fig,ax = plt.subplots(figsize=(15,8))
sns.scatterplot(x='release_date', 
                y='worldwide_box_office', 
                hue='mcu_phase', 
                data=mcu_data, 
                palette='bright')
plt.ylabel('Worldwide Box Office Earnings')
plt.xlabel('Release Date')
plt.title('Worldwide Earnings Over Time Colored by Phase')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.barplot(x='movie_title', 
            y='points_scored', 
            data=mcu_data, 
            hue='mcu_phase', 
            palette='bright',
            dodge=False)
plt.xticks(rotation=90)
plt.ylabel('Points Scored')
plt.xlabel('Movie Title')
plt.title('Total Points Scored Across Best MCU Movie Evaluation')
plt.show()

# %%
phase_eval = mcu_data.groupby('mcu_phase').agg({
    'tomato_score': 'mean',
    'audience_score': 'mean',
    'opening_weekend': 'mean',
    'worldwide_box_office': 'mean',
    'net_profit': 'mean',
    'points_scored': 'mean'
})
